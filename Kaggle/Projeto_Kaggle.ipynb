# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi

# Configurar as credenciais da API do Kaggle
os.environ['USUARIO_KAGGLE'] = 'daniaalves'
os.environ['CHAVE_KAGGLE'] = '362590fdeafb25d53076af6477221e59'

# Inicializar a API e autenticar
api = KaggleApi()
api.authenticate()

# Baixar conjunto de dados
identificador_conjunto = 'thegunny86/santander-stocks-20042020'
api.dataset_download_files(identificador_conjunto)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thegunny86/santander-stocks-20042020

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# Conectar ao MySQL 
nome = 'root'
senha = '258201'
host = '127.0.0.1'
porta = '3306'
engine = create_engine(f'mysql+pymysql://{nome}:{senha}@{host}:{porta}')

# Configuração para usar o banco 
banco = 'santander'
engine = create_engine(f'mysql+pymysql://{nome}:{senha}@{host}:{porta}/{banco}')

# %%
import pandas as pd
from sqlalchemy import create_engine

# Carregar os dados do CSV
dados = pd.read_csv(r'C:\Users\danie\OneDrive\Área de Trabalho\Kaggle\santander_stocks_2004_2020.csv')


# Para inserir os nomes exatos das colunas 
dados.columns = ['Date', 'Maxima', 'Minima', 'Abertura', 'Fechamento', 'Volume','Fechamento Ajustado']

# Conectar ao banco de dados 
connection_string = 'mysql+pymysql://root:258201@127.0.0.1:3306/santander'
engine = create_engine(connection_string)

# Inserir os dados na tabela
dados.to_sql('santander', con=engine, if_exists='append', index=False)
# Out:
# 4027

# %%
import pandas as pd

# Certifique-se de que a coluna 'Data'
dados['Date'] = pd.to_datetime(dados['Date'])

# dados do período de 2004 a 2020
dados_filtrados = dados[(dados['Date'].dt.year >= 2004) & (dados['Date'].dt.year <= 2020)]

# informações do DataFrame 
print(dados_filtrados.info())

# análises estatísticas 
print(dados_filtrados.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4027 entries, 0 to 4026
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4027 non-null   datetime64[ns]
#  1   High       4027 non-null   float64
#  2   Low        4027 non-null   float64
#  3   Open       4027 non-null   float64
#  4   Close      4027 non-null   float64
#  5   Volume     4027 non-null   float64
#  6   Adj Close  4027 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 220.4 KB
# None
#                                 Date         High          Low         Open  \
# count                           4027  4027.000000  4027.000000  4027.000000
# mean   2011-12-31 23:20:18.475291904    10.141130     9.945766    10.043365
# min              2004-01-02 00:00:00     3.710000     3.600000     3.690000
# 25%              2008-01-02 12:00:00     6.575000     6.480000     6.535000
# ...

# %%
# Verificar informações 
print(dados.info())

# Realizar análises estatísticas básicas
print(dados.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4027 entries, 0 to 4026
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4027 non-null   datetime64[ns]
#  1   High       4027 non-null   float64
#  2   Low        4027 non-null   float64
#  3   Open       4027 non-null   float64
#  4   Close      4027 non-null   float64
#  5   Volume     4027 non-null   float64
#  6   Adj Close  4027 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 220.4 KB
# None
#                                 Date         High          Low         Open  \
# count                           4027  4027.000000  4027.000000  4027.000000
# mean   2011-12-31 23:20:18.475291904    10.141130     9.945766    10.043365
# min              2004-01-02 00:00:00     3.710000     3.600000     3.690000
# 25%              2008-01-02 12:00:00     6.575000     6.480000     6.535000
# ...

# %%
import pandas as pd


dados = pd.read_csv(r'C:\Users\danie\OneDrive\Área de Trabalho\Kaggle\santander_stocks_2004_2020.csv')  


#filtrar para o ano de 2019
dados['Date'] = pd.to_datetime(dados['Date'])
dados_2019 = dados[dados['Date'].dt.year == 2019]

# Verificar informações do DataFrame de 2019
print(dados_2019.info())

# Realizar análises estatísticas básicas
print(dados_2019.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252 entries, 3775 to 4026
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    datetime64[ns]
#  1   High       252 non-null    float64
#  2   Low        252 non-null    float64
#  3   Open       252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Volume     252 non-null    float64
#  6   Adj Close  252 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 15.8 KB
# None
#                                 Date        High         Low        Open  \
# count                            252  252.000000  252.000000  252.000000
# mean   2019-07-02 09:02:51.428571392    4.439484    4.375675    4.408849
# min              2019-01-02 00:00:00    3.720000    3.650000    3.690000
# 25%              2019-04-02 18:00:00    4.070000    4.010000    4.030000
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Carregar dados do arquivo CSV
caminho_csv = r'C:\Users\danie\OneDrive\Área de Trabalho\Kaggle\santander_stocks_2004_2020.csv'
dados = pd.read_csv(caminho_csv)

# Verificar as colunas do DataFrame
print("Colunas do DataFrame:", dados.columns)

# Filtrar apenas os dados de 2019
dados['Date'] = pd.to_datetime(dados['Date'])
dados_2019 = dados[dados['Date'].dt.year == 2019]

# Credenciais de conexão
nome = 'root'
senha = '258201'
host = '127.0.0.1'
porta = 3306
db = 'banco_tratado'

# Conectar ao MySQL
connection_string = f'mysql+pymysql://{nome}:{senha}@{host}:{porta}/{db}'
engine = create_engine(connection_string)

# Inserir dados no banco de dados
tabela_destino = 'dados_tratados_santander_2019'
dados_2019.to_sql(tabela_destino, con=engine, if_exists='append', index=False)
# Out:
# Colunas do DataFrame: Index(['Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')
# 252
